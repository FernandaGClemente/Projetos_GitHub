# %% [markdown]
# # Análise de dados de vendas
#
# Este é um projeto de análise de dados que se concentra nos dados de vendas de uma empresa de varejo. Os dados são armazenados em um banco de dados do Microsoft SQL Server e as consultas SQL são usadas para extrair e analisar os dados.
#
# ## Conjunto de dados
#
# O conjunto de dados usado neste projeto consiste em várias tabelas:
#
# - `vendas`: contém informações sobre cada venda, incluindo a data da venda, ID do cliente e valor total da venda.
# - `products`: contém informações sobre cada produto, incluindo ID do produto, nome e preço.
# - `clientes`: contém informações sobre cada cliente, incluindo o ID do cliente, nome e endereço de e-mail.
#
# ## Ferramentas usadas
#
# As seguintes ferramentas foram utilizadas neste projeto:
#
# -Microsoft SQLServer
# - Linguagem SQL
# - Notebook Jupyter
# - Pitão
#
# ## Análise
#
# A análise neste projeto inclui o seguinte:
#
# - Tendências de vendas ao longo do tempo
# - Produtos mais vendidos
# - Comportamento de compra do cliente
# - Vendas por região geográfica
#
# ## Uso
#
# Para executar este projeto, você precisará ter o Microsoft SQL Server instalado e em execução. Você também precisará ter o Python e o Jupyter Notebook instalados.
#
# 1. Clone este repositório em sua máquina local.
# 2. Abra `SalesDataAnalysis.ipynb` no Jupyter Notebook.
# 3. Atualize as informações de conexão do banco de dados na primeira célula do notebook.
# 4. Execute as células do notebook para ver os resultados da análise.
#
# ## Conclusão
#
# Em conclusão, este projeto demonstra como as consultas SQL podem ser usadas para extrair e analisar dados de um banco de dados Microsoft SQL Server. A análise fornece insights sobre tendências de vendas, desempenho do produto e comportamento do cliente, que podem ser usados ​​para informar as decisões de negócios.

# %% [markdown]
# > https://data.research.cornell.edu/content/readme <br>
# > https://datadryad.org/stash/dataset/doi:10.5061/dryad.j512f21p <br>
# > https://www.usgs.gov/data-management/data-dictionaries

# %% [markdown]
# ##### Este arquivo README foi gerado em [AAAA-MM-DD] por [NOME]
#
# <br> <br>
#
# ##### INFORMAÇÕES GERAIS <br>
#
# ##### Título do conjunto de dados: <br>
#
# ##### < forneça pelo menos dois contatos >
# ##### Informações do autor/investigador principal
# ##### Nome:
# ##### ORCID:
# ##### Instituição:
# ##### Endereço:
# ##### E-mail:
#
# <br>
#
# ##### Informações do autor/associado ou co-investigador
# ##### Nome:
# ##### ORCID:
# ##### Instituição:
# ##### Endereço:
# ##### E-mail:
#
# <br>
#
# ##### Informações de contato do autor/alternativo
# ##### Nome:
# ##### ORCID:
# ##### Instituição:
# ##### Endereço:
# ##### E-mail:
#
# <br>
#
# ##### Data da coleta de dados: < forneça uma única data, intervalo ou data aproximada; formato sugerido AAAA-MM-DD >
# ##### Localização geográfica da coleta de dados: <forneça latitude, longitude ou cidade/região, estado, país>
# ##### Informações sobre as fontes de financiamento que apoiaram a coleta dos dados: <br>
#
# <br> <br>
#
# ##### COMPARTILHAMENTO/ACESSO A INFORMAÇÕES <br>
#
# ##### Licenças/restrições impostas aos dados:
# ##### Links para publicações que citam ou usam os dados:
# ##### Links para outros locais acessíveis publicamente dos dados:
# ##### Links/relações para conjuntos de dados auxiliares:
#
# <br>
#
# ##### Os dados foram derivados de outra fonte?
# ##### Se sim, liste a(s) fonte(s): <br>
#
# ##### Citação recomendada para este conjunto de dados: <br>
#
# <br><br>
#
# ##### VISÃO GERAL DE DADOS E ARQUIVOS <br>
#
# ##### Lista de arquivos: < lista todos os arquivos (ou pastas, conforme apropriado para a organização do conjunto de dados) contidos no conjunto de dados, com uma breve descrição >
# ##### Relacionamento entre arquivos, se importante:
# ##### Dados relacionados adicionais coletados que não foram incluídos no pacote de dados atual: <br>
#
# ##### Existem várias versões do conjunto de dados?
# ##### Se sim, nome do(s) arquivo(s) atualizado(s):
# ##### Por que o arquivo foi atualizado?
# ##### Quando o arquivo foi atualizado? <br>
#
# <br><br>
#
# ##### INFORMAÇÕES METODOLÓGICAS <br>
#
# ##### Descrição dos métodos usados para coleta/geração de dados: < incluir links ou referências a publicações ou outra documentação contendo desenho experimental ou protocolos usados na coleta de dados >
# ##### Métodos para processar os dados: < descrever como os dados enviados foram gerados a partir dos dados brutos ou coletados >
# ##### Informações específicas do instrumento ou software necessárias para interpretar os dados: < inclua o nome completo e a versão do software e quaisquer pacotes ou bibliotecas necessárias para executar scripts >
# ##### Padrões e informações de calibração, se apropriado:
# ##### Condições ambientais/experimentais:
# ##### Descreva quaisquer procedimentos de garantia de qualidade realizados nos dados:
# ##### Pessoas envolvidas na coleta, processamento, análise e/ou envio de amostras: <br>
#
# <br><br>
#
# ##### INFORMAÇÕES ESPECÍFICAS DE DADOS PARA: [NOME DO ARQUIVO]
# ##### < repita esta seção para cada conjunto de dados, pasta ou arquivo, conforme apropriado > <br>
#
# ##### Número de variáveis:
# ##### Número de casos/linhas:
# ##### Lista de Variáveis: < listar nome(s) de variável, descrição(ões), unidade(s) e rótulos de valor conforme apropriado para cada >
# ##### Códigos de dados ausentes: <listar código/símbolo e definição>
# ##### Formatos especializados ou outras abreviaturas usadas:

# %% [markdown]
# # modelo-README.md
# Modelo (template) de README para utilizar nas documentações dos seus projetos no GitHub. Deixe sua ⭐ se curtiu o template, para ficar salvo e utilizar depois.
#
# # Título/Nome do projeto
#
# Descreva brevemente o seu projeto. Aqui você pode utilizar texto e também imagens/diagramas.
#
# * O [Mermaid](https://mermaid.live/edit#pako:eNpVkE1uwjAQha9izapIZFGWWVSCBFZUVCq7mMXInjSW_Fdji6Ikp2HRg3CxmmRDZzV633uj0etBOElQQqvdRXQYIjvW3LI862bttRJ4_73fHHs9saJ4GwJ9JzrHgW1enulqMWc2DxOr-u0PGa_dOKvVFD1YGljd7NFH50_P5HhxA9s26qNzlv6TLlBO7ZoWyxYLgYFVGCYLLMFQMKhk_r5_KBxiR4Y4lHmV1GLSkQO3Y7Ziiu7zagWUMSRaQvISI9UKvwIayLf1OaskVXThfW5kKmb8AyAeX3o) é uma opção bem legal para diagramas e você consegue utilizar diretamente no README.md:
#
# [![](https://mermaid.ink/img/pako:eNpVkE1uwjAQha9izapIZFGWWVSCBFZUVCq7mMXInjSW_Fdji6Ikp2HRg3CxmmRDZzV633uj0etBOElQQqvdRXQYIjvW3LI862bttRJ4_73fHHs9saJ4GwJ9JzrHgW1enulqMWc2DxOr-u0PGa_dOKvVFD1YGljd7NFH50_P5HhxA9s26qNzlv6TLlBO7ZoWyxYLgYFVGCYLLMFQMKhk_r5_KBxiR4Y4lHmV1GLSkQO3Y7Ziiu7zagWUMSRaQvISI9UKvwIayLf1OaskVXThfW5kKmb8AyAeX3o?type=png)](https://mermaid.live/edit#pako:eNpVkE1uwjAQha9izapIZFGWWVSCBFZUVCq7mMXInjSW_Fdji6Ikp2HRg3CxmmRDZzV633uj0etBOElQQqvdRXQYIjvW3LI862bttRJ4_73fHHs9saJ4GwJ9JzrHgW1enulqMWc2DxOr-u0PGa_dOKvVFD1YGljd7NFH50_P5HhxA9s26qNzlv6TLlBO7ZoWyxYLgYFVGCYLLMFQMKhk_r5_KBxiR4Y4lHmV1GLSkQO3Y7Ziiu7zagWUMSRaQvISI9UKvwIayLf1OaskVXThfW5kKmb8AyAeX3o)
#
# - No site, vá no campo: Actions > Copy Markdown. Copie o link e cole no seu arquivo README.md e o diagrama estará lá.
#
#
# ### Tecnologias Utilizadas
#
# Liste as tecnologias (linguagens, ferramentas, bibliotecas) que você utilizou para elaborar o projeto. Essa parte é importante para quando um recrutador (que não tem conhecimento de programação) acessar o seu projeto, ele vai saber só olhando a documentação quais tecnologias você já conhece!
#
# Exemplo:
# * [Golang](https://github.com/golang/go)
# * [Docker](https://www.docker.com/)
# * [MySQL](https://www.mysql.com/)
#
# ## Dependências e Versões Necessárias
#
# Liste as dependências necessárias para rodar o projeto e as versões que você utilizou.
#
# * Docker - Versão: X.X
#
# ## Como rodar o projeto ✅
#
# Descreva o passo a passo necessário para rodar sua aplicação. Lembre-se: a pessoa nunca rodou seu projeto. Não tenha medo de detalhar o máximo possível. Isso é necessário!
#
# Uma boa forma de descrever o passo a passo é:
#
# ```
# Comando 1
# ```
#
# Depois, rode o seguinte comando:
#
# ```
# Comando 2
# ```
#
# Deixe claro como a pessoa pode confirmar que a aplicação está rodando da forma correta. Pode ser com prints ou a mensagem que ela deve esperar.
#
# ## Como rodar os testes
#
# Explique como rodar os testes da aplicação. Exemplo de um comando usando Makefile para rodar os testes:
#
# ```
# make test
# ```
#
# ## 📌 (Título) - Informações importantes sobre a aplicação (exemplo) 📌
#
# Esse é o local para você preencher com outras informações que possam ser importantes para a aplicação. Coloquei um exemplo de título, mas você deve preencher de acordo com a necessidade do projeto. Pode ser que não seja necessário.
#
# Um bom exemplo: se você estiver construindo uma API, liste as rotas da aplicação e quais serão os seus retornos. Isso facilita para quem vai consumir a API.
#
#
# ## ⚠️ Problemas enfrentados
#
# Liste os problemas que você enfrentou construindo a aplicação e como você resolveu cada um deles. Você que desenvolveu o projeto é a pessoa que mais conhece/entende os possíveis problemas que uma pessoa pode enfrentar rodando a aplicação. Compartilhe esse conhecimento e facilite a vida da pessoa descrevendo-os.
#
# Exemplo:
#
# ### Problema 1:
# Descrição do problema
# * Como solucionar: explicar a solução.
#
# ### Problema 2:
# Descrição do problema
# * Como solucionar: explicar a solução.
#
# ## ⏭️ Próximos passos
#
# Descreva se você pretende, pensou ou gostaria de elaborar uma nova feature para o seu projeto definindo os próximos passos.
